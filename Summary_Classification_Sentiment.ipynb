# %% [markdown]
# <a href="https://colab.research.google.com/github/drmehmetyegin/FeniksPolitik-Webscraping-and-Summary-Project/blob/main/Summary_Classification_Sentiment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df0=pd.read_csv('rows.csv')
df0.head(7)
# Out:
#    Unnamed: 0            author  \
# 0           0  Abdulkadir Selvi
# 1           1  Abdulkadir Selvi
# 2           2  Abdulkadir Selvi
# 3           3  Abdulkadir Selvi
# 4           4  Abdulkadir Selvi
# 5           5  Abdulkadir Selvi
# 6           6  Abdulkadir Selvi
#
#                                                title             date  \
# 0  MİT ile MOSSAD arasında casuslar savaşı mı yaş...  Aralık 08, 2023
# 1  Denizbank yöneticileri Ponzi Seçil olayında if...  Aralık 07, 2023
# 2   İçişleri Bakanı ile konuştuklarımız ve izlenimim  Aralık 06, 2023
# 3  İYİ Parti’nin kararı seçim sonuçlarını etkiley...  Aralık 05, 2023
# 4  İYİ Parti CHP ile seçim işbirliği kararı alaca...  Aralık 04, 2023
# 5  Cumhurbaşkanı Erdoğan Dubai dönüşü gazeteciler...  Aralık 03, 2023
# 6  Ponzi Seçil’in verdiği şifre ve Denizbank’ın d...  Aralık 01, 2023
#
#                                                 text
# 0  Haberin Devamı1. ERDOĞAN UYARDICumhurbaşkanı E...
# ...

# %%
df1=pd.read_csv('rows1.csv')
df1.head(7)
# Out:
#    Unnamed: 0         author  \
# 0           0  MELİH ALTINOK
# 1           1  MELİH ALTINOK
# 2           2  MELİH ALTINOK
# 3           3  MELİH ALTINOK
# 4           4  MELİH ALTINOK
# 5           5  MELİH ALTINOK
#
#                                                title                 date  \
# 0                 Johnson’ın özrü kabahatinden büyük       08 Aralık 2023
# 1  2019 ile 2024 İstanbul seçimleri arasındaki fa...   06 Aralık 2023, Ça
# 2                         Çarşı buna karşı değil mi?  04 Aralık 2023, Paz
# 3              Seçil Erzan davasında mağdur yok gibi      03 Aralık 2023,
# 4          O karedeki tek Selanikli Atatürk, o da...  02 Aralık 2023, Cum
# 5                 Elon Musk hata yaptığının farkında       01 Aralık 2023
#
#                                                 text
# 0  \nİngiltere'nin eski Başbakanı Boris Johnson, ...
# 1  \nİyi Parti'nin 2024 yerel seçimlerine bağımsı...
# 2  \nYer, Beşiktaş Spor Kulübü'nün bir toplantısı...
# ...

# %%
df2=pd.read_csv('rows_mo.csv')
df2.head(7)
# Out:
#    Unnamed: 0       author                                              title  \
# 0           0  MAHMUT ÖVÜR             CHP ile İyi Parti’nin Ankara pazarlığı
# 1           1  MAHMUT ÖVÜR  ‘AK Parti’ye yarar diye para getirmek istemiyo...
# 2           2  MAHMUT ÖVÜR    Akşener siyaseti ve listelerin ‘dolarla’ satışı
# 3           3  MAHMUT ÖVÜR            İyi Parti’nin hamlesi CHP’yi karıştırdı
# 4           4  MAHMUT ÖVÜR                        Sıra CHP-HEDEP pazarlığında
# 5           5  MAHMUT ÖVÜR      Başkan Erdoğan, Lula, Sanchez ve Attila İlhan
#
#                   date                                               text
# 0       01 Aralık 2023  \nYine başa döndük. Ekranda beliren iki yüzü, ...
# 1  02 Aralık 2023, Cum  \nGündemde yerel seçim olsa da durdurulamayan ...
# 2      03 Aralık 2023,  \nGünlerdir medyada milyon dolarların döndüğü ...
# 3       05 Aralık 2023  \nNihayet İyi Parti kararını verdi. Yerel seçi...
# ...

# %%
df3=pd.read_csv('rows_tg.csv')
df3.head(7)
# Out:
#    Unnamed: 0          author                                         title  \
# 0           0    Turgay Güler  İYİ Parti'yi döviz bürolarıyla yola getirmek
# 1           1    Turgay Güler                                     İnanılmaz
# 2           2  Kurtuluş Tayiz                    Akşener ve siyasi harakiri
# 3           3  Kurtuluş Tayiz                       Kara para beyaz soygun…
# 4           4  Kurtuluş Tayiz                           Akşener'in intikamı
# 5           5  Kurtuluş Tayiz                   AK Parti'nin İstanbul adayı
# 6           6     Hikmet Genç               HEDEP/PKK ile idare edin artık!
#
#             date                                               text
# 0  6 Aralýk 2023  \nÖnce Pelin  Batu'nun ismi geçiyordu. Yazmışt...
# 1  5 Aralýk 2023  \nBeyimiz uzunca bir aradan  sonra 'İBB' eksen...
# 2  1 Aralýk 2023  \nCHP Genel Başkanı Özgür Özel, partisinin yer...
# 3  4 Aralýk 2023  \nGörgüsüz, sonradan görme ve ne oldum delisi ...
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  10 non-null     int64
#  1   author      10 non-null     object
#  2   title       10 non-null     object
#  3   date        10 non-null     object
#  4   text        10 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 528.0+ bytes

# %%
df3.date.apply(lambda x: df3.date.astype(str))
df3
# Out:
#    Unnamed: 0          author                                           title  \
# 0           0    Turgay Güler    İYİ Parti'yi döviz bürolarıyla yola getirmek
# 1           1    Turgay Güler                                       İnanılmaz
# 2           2  Kurtuluş Tayiz                      Akşener ve siyasi harakiri
# 3           3  Kurtuluş Tayiz                         Kara para beyaz soygun…
# 4           4  Kurtuluş Tayiz                             Akşener'in intikamı
# 5           5  Kurtuluş Tayiz                     AK Parti'nin İstanbul adayı
# 6           6     Hikmet Genç                 HEDEP/PKK ile idare edin artık!
# 7           7     Hikmet Genç     O iki kriter varsa, soykırım meşrulaşırmış!
# 8           8     Hikmet Genç  ‘İyi polis-kötü polis'i oynamaya başladılar...
# 9           9     Hikmet Genç  Hiç değişmeyen “CHP/HEDEP tezkere kardeşliği!”
#
#             date                                               text
# ...

# %%
df3.to_excel('row30.xlsx', index=False)

# %%
df4=pd.read_csv('rows_zs.csv')
df4.head(7)
# Out:
#    Unnamed: 0       author                                      title  \
# 0           0  Zafer Şahin  Mesele Gazze değil sen hala anlamadın mı?
# 1           1  Zafer Şahin                   Anketteki İsrail çatlağı
#
#              date                                               text
# 0  08 Aralık 2023  İsrail Cumhurbaşkanı Herzog’un niyeyse üstünde...
# 1  05 Aralık 2023  İstanbul merkezli İVEM Araştırma’nın Aralık ay...

# %%
df_all=pd.concat([df0, df1, df2, df3, df4])
df_all
# Out:
#    Unnamed: 0            author  \
# 0           0  Abdulkadir Selvi
# 1           1  Abdulkadir Selvi
# 2           2  Abdulkadir Selvi
# 3           3  Abdulkadir Selvi
# 4           4  Abdulkadir Selvi
# 5           5  Abdulkadir Selvi
# 6           6  Abdulkadir Selvi
# 0           0     MELİH ALTINOK
# 1           1     MELİH ALTINOK
# 2           2     MELİH ALTINOK
# 3           3     MELİH ALTINOK
# 4           4     MELİH ALTINOK
# 5           5     MELİH ALTINOK
# 0           0       MAHMUT ÖVÜR
# 1           1       MAHMUT ÖVÜR
# 2           2       MAHMUT ÖVÜR
# 3           3       MAHMUT ÖVÜR
# 4           4       MAHMUT ÖVÜR
# 5           5       MAHMUT ÖVÜR
# 0           0      Turgay Güler
# 1           1      Turgay Güler
# 2           2    Kurtuluş Tayiz
# 3           3    Kurtuluş Tayiz
# 4           4    Kurtuluş Tayiz
# 5           5    Kurtuluş Tayiz
# 6           6       Hikmet Genç
# 7           7       Hikmet Genç
# 8           8       Hikmet Genç
# ...

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31 entries, 0 to 1
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  31 non-null     int64
#  1   author      31 non-null     object
#  2   title       31 non-null     object
#  3   date        31 non-null     object
#  4   text        31 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 1.5+ KB

# %%
df
# Out:
#     index            author  \
# 0       1  ABDULKADIR SELVI
# 1       2  ABDULKADIR SELVI
# 2       3  ABDULKADIR SELVI
# 3       4  ABDULKADIR SELVI
# 4       5  ABDULKADIR SELVI
# 5       6  ABDULKADIR SELVI
# 6       7  ABDULKADIR SELVI
# 7       8     MELİH ALTINOK
# 8       9     MELİH ALTINOK
# 9      10     MELİH ALTINOK
# 10     11     MELİH ALTINOK
# 11     12     MELİH ALTINOK
# 12     13     MELİH ALTINOK
# 13     14       MAHMUT ÖVÜR
# 14     15       MAHMUT ÖVÜR
# 15     16       MAHMUT ÖVÜR
# 16     17       MAHMUT ÖVÜR
# 17     18       MAHMUT ÖVÜR
# 18     19       MAHMUT ÖVÜR
# 19     20      TURGAY GÜLER
# 20     21      TURGAY GÜLER
# 21     22    KURTULUŞ TAYIZ
# 22     23    KURTULUŞ TAYIZ
# 23     24    KURTULUŞ TAYIZ
# 24     25    KURTULUŞ TAYIZ
# 25     26       HIKMET GENÇ
# 26     27       HIKMET GENÇ
# 27     28       HIKMET GENÇ
# 28     29       HIKMET GENÇ
# 29     30       ZAFER ŞAHIN
# 30     31       ZAFER ŞAHIN
#
# ...

# %%
df.text.loc[0]
# Out:
# '1. ERDOĞAN UYARDICumhurbaşkanı Erdoğan, “Her şeyden önce bu haberi yapanlar demek ki Türkiye’yi tanımıyorlar. Türkleri tanımıyorlar. Bizi tanımıyorlar. Böyle bir yanlışa tevessül etmeleri halinde şunu bilmeleri gerekir ki bunun bedelini, bunun faturasını çok ama çok ağır öderler” dedi.Erdoğan’ın bu uyarısının sahada ne anlama geldiğini en iyi MOSSAD bilir.2. İSTİHBARATIN TEPKİSİAnadolu Ajansı’na konuşan istihbarat yetkilileri, muhtelif istihbarat servislerinin daha önce de Türkiye Cumhuriyeti topraklarında yasadışı faaliyetler gerçekleştirmeye çalıştığını anımsatarak, hiçbir servisin bu tür operasyonlarına müsaade edilmeyeceğini vurguladı.3. MOSSAD ENSELENMİŞTİİstihbarat yetkililerinin uyarısını en iyi MOSSAD bilir. Çünkü 2021 yılında İstanbul’da Filistinli aktivistlere yönelik suikast hazırlığı içinde olan 7 MOSSAD ajanı yakalanmıştı. MOSSAD’ın güvenli evlerine baskın yapılmış Türkiye’deki hücreleri çökertilmişti. Ajanlar şimdi cezaevinde gün dolduruyorlar.4. MOSSAD’IN İMAJI SARSIL
# ...

# %%
# !pip install openai

# %%
# !pip install --upgrade typing_extensions
# !pip uninstall openai
# !pip install openai
# Out:
# ...
# Found existing installation: openai 1.6.0
# Uninstalling openai-1.6.0:
#   Would remove:
#     /usr/local/bin/openai
#     /usr/local/lib/python3.10/dist-packages/openai-1.6.0.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/openai/*
# Proceed (Y/n)? y
#   Successfully uninstalled openai-1.6.0
# ...
#   Using cached openai-1.6.0-py3-none-any.whl (225 kB)
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires tiktoken, which is not installed.
# ...

# %%
OPENAI_API_KEY="sk-2l7Xm2niLDGTHHmkp3ntT3BlbkFJOwgixkFkI**********"

# %%
transcription=df.text.loc[0]

# %%
from openai import OpenAI

client = OpenAI(api_key=api_key)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-13-05a41c16feb8> in <cell line: 1>()
# ----> 1 from openai import OpenAI
#       2
#       3 client = OpenAI(api_key=api_key)
#
# /usr/local/lib/python3.10/dist-packages/openai/__init__.py in <module>
#       6 from typing_extensions import override
#       7
# ----> 8 from . import types
#       9 from ._types import NoneType, Transport, ProxiesTypes
#      10 from ._utils import file_from_path
#
# /usr/local/lib/python3.10/dist-packages/openai/types/__init__.py in <module>
#       3 from __future__ import annotations
#       4
# ----> 5 from .edit import Edit as Edit
#       6 from .image import Image as Image
#       7 from .model import Model as Model
#
# /usr/local/lib/python3.10/dist-packages/openai/types/edit.py in <module>
#       4 from typing_extensions import Literal
#       5
# ...

# %%
def key_points_extraction(transcription):
    response = client.chat.completions.create(
        model="gpt-4",
        temperature=0,
        messages=[
            {
                "role": "system",
                "content": "You are a proficient AI with a specialty in distilling information into key points. Based on the following text, identify and list the main points that were discussed or brought up. These should be the most important ideas, findings, or topics that are crucial to the essence of the discussion. Your goal is to provide a list that someone could read to quickly understand what was talked about."
            },
            {
                "role": "user",
                "content": transcription
            }
        ]
    )
    return response.choices[0].message.content

# %%
transcription1=df.text.loc[1]

# %%
def key_points_extraction(transcription1):
    response = client.chat.completions.create(
        model="gpt-3.5-turbo",
        temperature=0,
        messages=[
            {
                "role": "system",
                "content": "You are a proficient AI with a specialty in distilling information into key points. Based on the following text, identify and list the main points that were discussed or brought up. These should be the most important ideas, findings, or topics that are crucial to the essence of the discussion. Your goal is to provide a list that someone could read to quickly understand what was talked about."
            },
            {
                "role": "user",
                "content": transcription
            }
        ]
    )
    return response.choices[0].message.content

# %%
key_points_extraction(transcription1)
# Out:
# "Main points discussed in the text:\n\n1. Turkish President Erdogan warns those who underestimate Turkey and its people, stating that they will pay a heavy price.\n2. Intelligence officials emphasize that no illegal activities by foreign intelligence services will be tolerated in Turkey.\n3. Mossad, the Israeli intelligence agency, had previously been involved in illegal activities in Turkey, leading to the arrest of 7 Mossad agents in Istanbul in 2021.\n4. The recent actions of Hamas have damaged Mossad's reputation and become a subject of ridicule.\n5. Mossad sought assistance from the Turkish intelligence agency, MIT, in rescuing hostages, and MIT successfully negotiated the release of some hostages during a temporary ceasefire.\n6. In a joint operation, MIT and Istanbul Police prevented an assassination attempt by Iranian intelligence on an Israeli tourist group in 2022.\n7. Tensions and conflicts within the Good Party (IYI Parti) have increased, particularly regarding the influe
# ...

# %%
def abstract_summary_extraction(transcription1):
    response = client.chat.completions.create(
        model="gpt-4",
        temperature=0,
        messages=[
            {
                "role": "system",
                "content": "You are a highly skilled AI trained in language comprehension and summarization. I would like you to read the following text and summarize it as concise as possible. Aim to retain the most important points, providing a coherent and readable summary that could help a person understand the main points of the discussion without needing to read the entire text. Please avoid unnecessary details or tangential points."
            },
            {
                "role": "user",
                "content": transcription
            }
        ]
    )
    return response.choices[0].message.content

# %%
abstract_summary_extraction(transcription1)
# Out:
# "Turkish President Erdoğan warned against any potential illegal activities by foreign intelligence services on Turkish soil, stating that those involved would face severe consequences. This follows previous incidents where agents from Israel's intelligence agency, MOSSAD, were arrested in Turkey. Turkish intelligence officials reiterated that no foreign operations would be allowed in the country. In 2021, seven MOSSAD agents were arrested in Istanbul while preparing for an assassination. The image of MOSSAD was further damaged when it failed to gather intelligence on a Hamas operation and had to request assistance from Turkey's intelligence agency, MİT. \n\nIn political news, tensions are rising within the CHP and İYİ Party due to the increasing influence of Istanbul Mayor Ekrem İmamoğlu. After İYİ Party leader Meral Akşener criticized İmamoğlu, several party members resigned. İmamoğlu is also reportedly leading alliance talks with Muharrem İnce, offering him the candidacy for İzmir'
# ...

# %%
def abstract_summary_extraction(transcription):
    response = client.chat.completions.create(
        model="gpt-4",
        temperature=0,
        messages=[
            {
                "role": "system",
                "content": "You are a highly skilled AI trained in language comprehension and summarization. I would like you to read the following text and summarize it into a concise abstract paragraph. Aim to retain the most important points, providing a coherent and readable summary that could help a person understand the main points of the discussion without needing to read the entire text. Please avoid unnecessary details or tangential points."
            },
            {
                "role": "user",
                "content": transcription
            }
        ]
    )
    return response['choices'][0]['message']['content']

# %%
abstract_summary_extraction(transcription)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-777af9881099> in <cell line: 1>()
# ----> 1 abstract_summary_extraction(transcription)
#
# <ipython-input-57-16c68e3d2e64> in abstract_summary_extraction(transcription)
#      14         ]
#      15     )
# ---> 16     return response['choices'][0]['message']['content']
#
# TypeError: 'ChatCompletion' object is not subscriptable

# %%
r="ChatCompletion(id='chatcmpl-8XVwiukarUdZheCYBhyEthRurXpQL', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="1. President Erdoğan warned those who do not understand Turkey and its people, stating that they would pay a heavy price for any missteps.\n2. Intelligence officials emphasized that no intelligence service will be allowed to carry out illegal activities on Turkish soil.\n3. In 2021, seven MOSSAD agents preparing for an assassination of Palestinian activists in Istanbul were caught, damaging MOSSAD's image.\n4. After failing to gather intelligence on a Hamas operation on October 7, MOSSAD asked for help from MİT (Turkish National Intelligence Organization) to rescue hostages.\n5. In 2022, MİT and Istanbul Police prevented an assassination attempt on an Israeli tourist group by Iranian intelligence.\n6. The article suggests that if MOSSAD attempts any reckless actions, they will have to face the consequences.\n7. The issue of Ekrem İmamoğlu is growing within the CHP (Republican People's Party) and İYİ Party.\n8. After Meral Akşener targeted Ekrem İmamoğlu, resignations began in the İYİ Party.\n9. İstanbul Deputy Ayşe Sibel Yanıkömeroğlu resigned from the İYİ Party five hours after Akşener's speech.\n10. İYİ Party Ankara Deputy Yüksel Arslan suggested that İmamoğlu was behind the resignations.\n11. İmamoğlu is acting like the real general chairman within the CHP, leading to growing issues within the party.\n12. İmamoğlu is conducting alliance talks with Muharrem İnce, suggesting İzmir's mayoral candidacy to him.\n13. The CHP is experiencing a kind of İmamoğlu guardianship, with mayoral candidates preferring to meet with İmamoğlu rather than CHP General Chairman Özgür Özel.", role='assistant', function_call=None, tool_calls=None))], created=1702998316, model='gpt-4-0613', object='chat.completion', system_fingerprint=None, usage=CompletionUsage(completion_tokens=388, prompt_tokens=2334, total_tokens=2722))"
# Out:
#   File "<ipython-input-54-7b65f6b77de2>", line 1
# ...

# %%
ChatCompletion
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-9e8155a4ed78> in <cell line: 1>()
# ----> 1 ChatCompletion
#
# NameError: name 'ChatCompletion' is not defined

# %%
def abstract_summary_extraction(transcription):
    response = client.chat.completions.create(
        model="gpt-4",
        temperature=0,
        messages=[
            {
                "role": "system",
                "content": "You are a highly skilled AI trained in language comprehension and summarization. I would like you to read the following text and summarize it into a concise abstract paragraph. Aim to retain the most important points, providing a coherent and readable summary that could help a person understand the main points of the discussion without needing to read the entire text. Please avoid unnecessary details or tangential points."
            },
            {
                "role": "user",
                "content": transcription
            }
        ]
    )
    return response['choices'][0]['message']['content']

# %%
abstract_summary_extraction(transcription)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-777af9881099> in <cell line: 1>()
# ----> 1 abstract_summary_extraction(transcription)
#
# <ipython-input-38-16c68e3d2e64> in abstract_summary_extraction(transcription)
#      14         ]
#      15     )
# ---> 16     return response['choices'][0]['message']['content']
#
# TypeError: 'ChatCompletion' object is not subscriptable

# %%
abstract_summary_extraction(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-1ec55140e9c2> in <cell line: 1>()
# ----> 1 abstract_summary_extraction(a)
#
# <ipython-input-35-5782c6dc22b0> in abstract_summary_extraction(a)
#      14         ]
#      15     )
# ---> 16     return response['choices'][0]['message']['content']
#
# TypeError: 'ChatCompletion' object is not subscriptable

# %%
system= "Summarize this for a second-grade student:"

text= """Jupiter is the fifth planet from the Sun and the largest in the Solar System. It is a gas giant with a mass one-thousandth that of the Sun, but two-and-a-half times
that of all the other planets in the Solar System combined. Jupiter is one of the brightest objects visible to the naked eye in the night sky, and has been known to ancient
civilizations since before recorded history. It is named after the Roman god Jupiter.[19] When viewed from Earth, Jupiter can be bright enough for its reflected light to cast
visible shadows,[20] and is on average the third-brightest natural object in the night sky after the Moon and Venus."""

summarize(system, text)

# %%
from openai import OpenAI
client = OpenAI()

completion = client.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[
    {"role": "system", "content": "You are a poetic assistant, skilled in explaining complex programming concepts with creative flair."},
    {"role": "user", "content": "Compose a poem that explains the concept of recursion in programming."}
  ]
)

print(completion.choices[0].message)
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# <ipython-input-30-4feae2d5c9e3> in <cell line: 2>()
#       1 from openai import OpenAI
# ----> 2 client = OpenAI()
#       3
#       4 completion = client.chat.completions.create(
#       5   model="gpt-3.5-turbo",
#
# /usr/local/lib/python3.10/dist-packages/openai/_client.py in __init__(self, api_key, organization, base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#      90             api_key = os.environ.get("OPENAI_API_KEY")
#      91         if api_key is None:
# ---> 92             raise OpenAIError(
#      93                 "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#      94             )
#
# ...

# %%
def contact_info(system, text):
  import openai

  response = openai.Completion.create(
    model="text-davinci-003",
    prompt=system+"\n\n"+text+"\nName: ",
    temperature=0,
    max_tokens=100,
    top_p=1.0,
    frequency_penalty=0.0,
    presence_penalty=0.0
  )
  return print("Name:"+response["choices"][0]["text"])

# %%
import openai

res = openai.ChatCompletion.create(
          model="gpt-3.5-turbo",
          messages=[
          {"role": "system", "content": f"{system}"},
          {"role": "user", "content": f"{user1}"},
          {"role": "assistant", "content": f"{assistant}"},
          {"role": "user", "content": f"{user2}"}
      ]
  )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-56692c2de98e> in <cell line: 3>()
#       4           model="gpt-3.5-turbo",
#       5           messages=[
# ----> 6           {"role": "system", "content": f"{system}"},
#       7           {"role": "user", "content": f"{user1}"},
#       8           {"role": "assistant", "content": f"{assistant}"},
#
# NameError: name 'system' is not defined
